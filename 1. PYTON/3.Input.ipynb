# %%
num1=input("Enter the num1:")
# Out:
# Enter the num1: 40

# %%
num2=input("Enter the num2:")
# Out:
# Enter the num2: 40

# %%
add=num1+num2

# %%
print(add)
# Out:
# 4040

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 40

# %%
num2=int(input("Enter the num2:"))
# Out:
# Enter the num2: 40

# %%
add=num1+num2

# %%
print(add)
# Out:
# 80

# %%
num1=int(input("Enter the num1:"))
# Out:
# Enter the num1: 10

# %%
num2=int(input("Enter the num2"))
# Out:
# Enter the num2 40

# %%
mul=num1*num2

# %%
print(mul)
# Out:
# 400

# %%
num1=int(input("Enter the name:"))

# %%
num1=int(input("Enter the num1:"))
