# %%
from multipleFunction import multipleFunction
# from filename import className

# %%
multipleFunction.Subfields()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 multipleFunction.Subfields()
#
# AttributeError: type object 'multipleFunction' has no attribute 'Subfields'

# %%
multipleFunction.OddEven()
# Out:
# Enter a number:  8787
# Odd number
# 'Odd number'

# %%
multipleFunction.Elegibilityformarriage()
# Out:
# Your Gender: Male
# Your Age: 29
# Eligibility for Marriage
# 'Eligibility for Marriage'

# %%
multipleFunction.percentage()
# Out:
# Enter Subject 1 marks: 98
# Enter Subject 2 marks: 87
# Enter Subject 3 marks: 95
# Enter Subject 4 marks: 95
# Enter Subject 5 marks: 93
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.6%

# %%
multipleFunction.triangle()
# Out:
# Height:32
# Breadth:34
# Area of Formula:(Height*Breadth)/2
# Area of Triangle:544.0
# Height1:2
# Height2:4
# Breadth:4
# Permiter formula: Height1+Height2+Breadth
# Permiter of Triangle: 10
