# %%
print(Welcome to Hope AI Govind)
# Out:
#   Cell In[1], line 1
#     print(Welcome to Hope AI Govind)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(Welcome to Hope AI Govind)
# Out:
#   Cell In[1], line 1
#     print(Welcome to Hope AI Govind)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print ("Welcome to Hope AI Govind")
# Out:
# Welcome to Hope AI Govind

# %%
Print ("Welcome to Hope AI Govind")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print ("Welcome to Hope AI Govind")
#
# NameError: name 'Print' is not defined
