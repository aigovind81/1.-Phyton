# %%
num=int(input("Enter the num,:"))

if num % 2 ==0:
    print("num is even")
else:
    print("num is odd")
# Out:
# Enter the num,: 4
# num is even

# %%
num=int(input("Enter the num,:"))

if num % 2 ==0:
    print("num is even")
else:
    print("num is odd")
# Out:
# Enter the num,: 5
# num is odd

# %%
num = 10 
if num % 2 == 0:
    print("num is even")
else:
    print("num is odd")
# Out:
# num is even

# %%
num = 11
if num % 2 == 0:
    print("num is even")
else:
    print("num is odd")
# Out:
# num is odd
