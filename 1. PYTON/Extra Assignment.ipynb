# %%
#print statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy input

# %%
num=input("Enter your institute name?:")
# Out:
# Enter your institute name?: HOPE AI

# %%
#Buy inputs

# %%
Name=input("Enter your name:")
Age=input("Enter your age:")
School=input("Enter your school name:")
Degree=input("Enter your degree:")
# Out:
# Enter your name: T.Govindasamy
# Enter your age: 47
# Enter your school name: E.R.Hr.S.S
# Enter your degree: B.E in Mechanical

# %%
#Addition

# %%
Num1=int(input("a=",))
Num2=int(input("b=",))
add=Num1+Num2 
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
a= 43
b= 34
print("add=",a+b)
# Out:
# add= 77

# %%
#Subraction

# %%
a= 43
b= 34
print("Sub=",a-b)
# Out:
# Sub= 9

# %%
Num1=int(input("a=",))
Num2=int(input("b=",))
sub=Num1-Num2 
print("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
#Multiplication

# %%
Num1=int(input("a=",))
Num2=int(input("b=",))
mul=Num1*Num2 
print("Mul=",mul)
# Out:
# a= 63
# b= 97
# Mul= 6111

# %%
#Division

# %%
a = 76
b = 31
div = a / b

print(f"a = {76}")
print(f"b = {31}")
print(f"Div = {div}")
# Out:
# a = 76
# b = 31
# Div = 2.4516129032258065

# %%
#Floor division

# %%
a = 76
b = 31
FloorDiv = a // b
print("a = 76")
print("b = 31")
print("Floor Div=",FloorDiv)
# Out:
# a = 76
# b = 31
# Floor Div= 2

# %%
How it works 
76 ÷ 31 = 2 with remainder 14
So, 76 % 31 = 14

# %%
a = 90
b = 20
FloorDiv = a // b
print("a = 90")
print("b = 20")
print("Floor Div=",FloorDiv)
# Out:
# a = 90
# b = 20
# Floor Div= 4

# %%
#Modulo

# %%
a = 76
b = 31
Modulo = a % b
print("a = 76")
print("b = 31")
print("Modulo=",Modulo)
# Out:
# a = 76
# b = 31
# Modulo= 14

# %%
#Power

# %%
a = 4
b = 4
power = a ** b
print("a = 4")
print("b = 4")
print("Power=",power)
# Out:
# a = 4
# b = 4
# Power= 256
