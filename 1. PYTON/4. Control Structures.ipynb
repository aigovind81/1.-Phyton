# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if (age==18):
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 40

# %%
if (age<18):
    print("Children")
else :
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 10

# %%
if (age<18):
    print("Children")
else :
    print("Adult")
# Out:
# Children

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 40

# %%
if (age<18):
    print("Children")
else :
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 5

# %%
if (age<18):
    print("Children")
elif(age<40):
    print("Adult")
elif(age<68):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Children

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 25

# %%
if (age<18):
    print("Children")
elif(age<40):
    print("Adult")
elif(age<68):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 50

# %%
if (age<18):
    print("Children")
elif(age<40):
    print("Adult")
elif(age<68):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Citizen

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 75

# %%
if (age<18):
    print("Children")
elif(age<40):
    print("Adult")
elif(age<68):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %%
lists=[10, 25, 45, 65, 75]

# %%
for age in lists:
    
    if(age < 18):
        print("Children")
    elif(age < 40):
        print("Adult")
    elif(age < 68):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Children
# Adult
# Citizen
# Citizen
# Senior Citizen

# %%
lists=[5, 15, 25, 75, 60]

# %%
for age in lists:
    
    if(age < 18):
        print("Children")
    elif(age < 40):
        print("Adult")
    elif(age < 68):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Children
# Children
# Adult
# Senior Citizen
# Citizen
